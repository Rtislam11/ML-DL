0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1149-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0455-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0645-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0515-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0671-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1267-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0278-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0533-0001-0002.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0665-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1287-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1295-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1316-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0486-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0405-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0401-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0256-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0531-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0741-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0451-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0550-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1019-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0429-0001-0002.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0382-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0538-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1323-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0816-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0409-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1279-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1253-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0818-0001-0002.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1001-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0476-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1005-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0687-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0977-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0618-0001-0002.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0915-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0682-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0564-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0941-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1116-0001-0002.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0140-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0954-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0539-0001-0002.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1256-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0635-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0608-0001-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1294-0001-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0555-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0573-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0675-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0676-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0407-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1220-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1360-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0255-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0523-0001-0002.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0842-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1017-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0849-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0999-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1344-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1096-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1348-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1145-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0178-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1016-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0333-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0559-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0423-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0512-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0729-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0909-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1035-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1151-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1040-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0506-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0176-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1306-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0876-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0895-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0652-0001-0002.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0955-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0582-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0832-0001-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0464-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1062-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0449-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0221-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0395-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0757-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0561-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1142-0001-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0273-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0485-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0579-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0494-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0602-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0919-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0836-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0244-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1156-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1261-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0501-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1198-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0929-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0711-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1205-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0464-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0894-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1204-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1174-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0448-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0949-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0275-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1232-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0822-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1334-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0463-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0671-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1385-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0580-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0234-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1266-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1338-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0691-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0539-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0650-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0657-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1288-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0193-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0880-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0545-0001-0002.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0911-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0664-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0596-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0656-0001-0002.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0125-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0435-0001-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1197-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0440-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0885-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0516-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0523-0001-0003.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0205-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0552-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0277-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0522-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0354-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1160-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-0389-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0162-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/NORMAL2-IM-1247-0001.jpeg
# /kaggle/input/datasets/rtislam/chest-xray/chest_xray/train/NORMAL/IM-0219-0001.jpeg

# %% [markdown]
# Set the Device (GPU)

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# train + val + test

# %%
import os
import shutil
import random
from sklearn.model_selection import train_test_split

random.seed(42)

SOURCE = "/kaggle/input/datasets/rtislam/chest-xray/chest_xray"
DEST = "/kaggle/working/chest_xray_split"

os.makedirs(DEST, exist_ok=True)

# %% [markdown]
# Create Class

# %%
classes = ["NORMAL", "BACTERIAL", "VIRAL"]

for split in ["train", "val", "test"]:
    for cls in classes:
        os.makedirs(os.path.join(DEST, split, cls), exist_ok=True)

# %% [markdown]
# Label All Images

# %%
all_images = []

for split in ["train", "val", "test"]:

    # NORMAL 
    normal_dir = os.path.join(SOURCE, split, "NORMAL")

    if os.path.exists(normal_dir):
        for f in os.listdir(normal_dir):
            if f.lower().endswith((".jpg", ".jpeg", ".png")):
                all_images.append((os.path.join(normal_dir, f), "NORMAL"))

    # PNEUMONIA
    pneumonia_dir = os.path.join(SOURCE, split, "PNEUMONIA")

    if os.path.exists(pneumonia_dir):
        for f in os.listdir(pneumonia_dir):

            name = f.lower()

            if "bacteria" in name:
                label = "BACTERIAL"

            elif "virus" in name:
                label = "VIRAL"

            else:
                continue

            all_images.append((os.path.join(pneumonia_dir, f), label))

print("Total Images:", len(all_images))
# Out:
# Total Images: 5856

# %% [markdown]
# Split Dataset

# %%
labels = [label for _, label in all_images]

train_data, temp_data = train_test_split(
    all_images,
    test_size=0.20,
    random_state=42,
    stratify=labels
)

temp_labels = [label for _, label in temp_data]

val_data, test_data = train_test_split(
    temp_data,
    test_size=0.50,
    random_state=42,
    stratify=temp_labels
)

# %% [markdown]
# Copy Images to Split Folders

# %%
def copy_images(data, split):

    for img_path, label in data:

        dst = os.path.join(
            DEST,
            split,
            label,
            os.path.basename(img_path)
        )

        shutil.copy(img_path, dst)

copy_images(train_data, "train")
copy_images(val_data, "val")
copy_images(test_data, "test")

# %% [markdown]
# Verify Dataset Split

# %%
for split in ["train", "val", "test"]:

    print("\n", split.upper())

    total = 0

    for cls in classes:

        folder = os.path.join(DEST, split, cls)

        count = len(os.listdir(folder))

        total += count

        print(f"{cls}: {count}")

    print("Total:", total)
# Out:
#  TRAIN
# NORMAL: 1266
# BACTERIAL: 2224
# VIRAL: 1194
# Total: 4684
#
#  VAL
# NORMAL: 159
# BACTERIAL: 278
# VIRAL: 149
# Total: 586
#
#  TEST
# NORMAL: 158
# BACTERIAL: 278
# VIRAL: 150
# Total: 586

# %% [markdown]
# Import Libraries

# %%
import os
import copy
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay
)

# %% [markdown]
# Dataset Paths

# %%
train_dir = "/kaggle/working/chest_xray_split/train"
val_dir   = "/kaggle/working/chest_xray_split/val"
test_dir  = "/kaggle/working/chest_xray_split/test"

print(train_dir)
print(val_dir)
print(test_dir)
# Out:
# /kaggle/working/chest_xray_split/train
# /kaggle/working/chest_xray_split/val
# /kaggle/working/chest_xray_split/test

# %% [markdown]
# Data Augmentation & Image Transforms

# %%
IMG_SIZE = 224
BATCH_SIZE = 32

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

test_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %% [markdown]
# Create Dataset and DataLoader

# %%
from torchvision import datasets

train_dataset = datasets.ImageFolder(
    root=train_dir,
    transform=train_transform
)

val_dataset = datasets.ImageFolder(
    root=val_dir,
    transform=test_transform
)

test_dataset = datasets.ImageFolder(
    root=test_dir,
    transform=test_transform
)

print("Classes:", train_dataset.classes)
print("Training Images:", len(train_dataset))
print("Validation Images:", len(val_dataset))
print("Testing Images:", len(test_dataset))

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Classes: ['BACTERIAL', 'NORMAL', 'VIRAL']
# Training Images: 4684
# Validation Images: 586
# Testing Images: 586

# %% [markdown]
# Build CNN Model

# %%
class PneumoniaCNN(nn.Module):
    def __init__(self, num_classes=3):
        super(PneumoniaCNN, self).__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),

            nn.Linear(256 * 14 * 14, 512),
            nn.ReLU(),
            nn.Dropout(0.5),

            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Dropout(0.5),

            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x


model = PneumoniaCNN(num_classes=3).to(device)

print(model)
# Out:
# PneumoniaCNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=50176, out_features=512, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=512, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Dropout(p=0.5, inplace=False)
#     (7): Linear(in_features=128, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# Loss Function, Optimizer & Scheduler

# %%
LEARNING_RATE = 0.001
NUM_EPOCHS = 30
WEIGHT_DECAY = 1e-4

criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.parameters(),
    lr=LEARNING_RATE,
    weight_decay=WEIGHT_DECAY
)

scheduler = optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=NUM_EPOCHS
)

print("Loss Function :", criterion)
print("Optimizer :", optimizer)
print("Scheduler :", scheduler)
# Out:
# Loss Function : CrossEntropyLoss()
# Optimizer : Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.001
#     lr: 0.001
#     maximize: False
#     weight_decay: 0.0001
# )
# Scheduler : <torch.optim.lr_scheduler.CosineAnnealingLR object at 0x7cd90a3004d0>

# %% [markdown]
# Training & Validation Loop

# %%
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

best_val_acc = 0.0

for epoch in range(NUM_EPOCHS):

    #Training
    model.train()

    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:

        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)

        loss = criterion(outputs, labels)

        loss.backward()

        optimizer.step()

        running_loss += loss.item() * images.size(0)

        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)

        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100 * correct / total

    train_losses.append(train_loss)
    train_accuracies.append(train_acc)

    #Validation

    model.eval()

    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():

        for images, labels in val_loader:

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            loss = criterion(outputs, labels)

            running_loss += loss.item() * images.size(0)

            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)

            correct += (predicted == labels).sum().item()

    val_loss = running_loss / len(val_loader.dataset)
    val_acc = 100 * correct / total

    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    scheduler.step()

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_pneumonia_model.pth")

    print(f"Epoch [{epoch+1}/{NUM_EPOCHS}]")
    print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}%")
    print(f"Val Loss:   {val_loss:.4f} | Val Acc:   {val_acc:.2f}%")
    print("-" * 50)

print("Training Finished!")
# Out:
# Epoch [1/30]
# Train Loss: 1.3312 | Train Acc: 56.23%
# Val Loss:   0.7243 | Val Acc:   65.87%
# --------------------------------------------------
# Epoch [2/30]
# Train Loss: 0.7753 | Train Acc: 64.43%
# Val Loss:   0.6614 | Val Acc:   68.94%
# --------------------------------------------------
# Epoch [3/30]
# Train Loss: 0.7115 | Train Acc: 67.70%
# Val Loss:   0.6273 | Val Acc:   68.77%
# --------------------------------------------------
# Epoch [4/30]
# Train Loss: 0.6756 | Train Acc: 69.21%
# Val Loss:   0.5854 | Val Acc:   70.14%
# --------------------------------------------------
# Epoch [5/30]
# Train Loss: 0.6445 | Train Acc: 71.09%
# Val Loss:   0.5602 | Val Acc:   73.89%
# --------------------------------------------------
# Epoch [6/30]
# Train Loss: 0.6127 | Train Acc: 72.95%
# Val Loss:   0.5927 | Val Acc:   75.94%
# --------------------------------------------------
# Epoch [7/30]
# Train Loss: 0.6320 | Train Acc: 72.69%
# Val Loss:   0.5459 | Val Acc:   74.57%
# --------------------------------------------------
# Epoch [8/30]
# Train Loss: 0.6127 | Train Acc: 73.57%
# Val Loss:   0.5369 | Val Acc:   75.09%
# --------------------------------------------------
# Epoch [9/30]
# Train Loss: 0.5927 | Train Acc: 75.13%
# Val Loss:   0.5234 | Val Acc:   78.67%
# --------------------------------------------------
# Epoch [10/30]
# Train Loss: 0.5748 | Train Acc: 75.94%
# Val Loss:   0.4946 | Val Acc:   78.67%
# --------------------------------------------------
# Epoch [11/30]
# Train Loss: 0.5702 | Train Acc: 76.17%
# Val Loss:   0.5439 | Val Acc:   76.62%
# --------------------------------------------------
# Epoch [12/30]
# Train Loss: 0.5649 | Train Acc: 76.22%
# Val Loss:   0.5403 | Val Acc:   80.89%
# --------------------------------------------------
# Epoch [13/30]
# Train Loss: 0.5545 | Train Acc: 76.02%
# Val Loss:   0.4871 | Val Acc:   80.72%
# --------------------------------------------------
# Epoch [14/30]
# Train Loss: 0.5553 | Train Acc: 76.84%
# Val Loss:   0.4970 | Val Acc:   80.89%
# --------------------------------------------------
# Epoch [15/30]
# Train Loss: 0.5390 | Train Acc: 76.94%
# Val Loss:   0.4960 | Val Acc:   77.82%
# --------------------------------------------------
# Epoch [16/30]
# Train Loss: 0.5336 | Train Acc: 77.69%
# Val Loss:   0.5146 | Val Acc:   80.55%
# --------------------------------------------------
# Epoch [17/30]
# Train Loss: 0.5170 | Train Acc: 78.03%
# Val Loss:   0.4705 | Val Acc:   80.03%
# --------------------------------------------------
# Epoch [18/30]
# Train Loss: 0.5146 | Train Acc: 77.75%
# Val Loss:   0.4922 | Val Acc:   80.38%
# --------------------------------------------------
# Epoch [19/30]
# Train Loss: 0.5085 | Train Acc: 78.61%
# Val Loss:   0.4749 | Val Acc:   80.89%
# --------------------------------------------------
# Epoch [20/30]
# Train Loss: 0.5033 | Train Acc: 78.91%
# Val Loss:   0.4820 | Val Acc:   81.40%
# --------------------------------------------------
# Epoch [21/30]
# Train Loss: 0.4939 | Train Acc: 78.86%
# Val Loss:   0.4826 | Val Acc:   80.03%
# --------------------------------------------------
# Epoch [22/30]
# Train Loss: 0.4866 | Train Acc: 78.89%
# Val Loss:   0.4800 | Val Acc:   80.20%
# --------------------------------------------------
# Epoch [23/30]
# Train Loss: 0.4812 | Train Acc: 79.04%
# Val Loss:   0.4687 | Val Acc:   81.06%
# --------------------------------------------------
# Epoch [24/30]
# Train Loss: 0.4813 | Train Acc: 79.36%
# Val Loss:   0.4726 | Val Acc:   80.72%
# --------------------------------------------------
# Epoch [25/30]
# Train Loss: 0.4715 | Train Acc: 79.06%
# Val Loss:   0.4646 | Val Acc:   81.57%
# --------------------------------------------------
# Epoch [26/30]
# Train Loss: 0.4652 | Train Acc: 80.12%
# Val Loss:   0.4579 | Val Acc:   81.40%
# --------------------------------------------------
# Epoch [27/30]
# Train Loss: 0.4635 | Train Acc: 80.02%
# Val Loss:   0.4576 | Val Acc:   80.89%
# --------------------------------------------------
# Epoch [28/30]
# Train Loss: 0.4626 | Train Acc: 79.44%
# Val Loss:   0.4597 | Val Acc:   81.06%
# --------------------------------------------------
# Epoch [29/30]
# Train Loss: 0.4534 | Train Acc: 80.29%
# Val Loss:   0.4550 | Val Acc:   81.23%
# --------------------------------------------------
# Epoch [30/30]
# Train Loss: 0.4646 | Train Acc: 79.50%
# Val Loss:   0.4554 | Val Acc:   81.23%
# --------------------------------------------------
# Training Finished!

# %% [markdown]
# Test Evaluation (Accuracy, Classification Report & Confusion Matrix)

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# Load best model
model.load_state_dict(torch.load("best_pneumonia_model.pth"))
model.eval()

all_labels = []
all_predictions = []

correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        all_labels.extend(labels.cpu().numpy())
        all_predictions.extend(predicted.cpu().numpy())

test_accuracy = 100 * correct / total

print(f"Test Accuracy: {test_accuracy:.2f}%")

print("\nClassification Report:\n")
print(classification_report(
    all_labels,
    all_predictions,
    target_names=["NORMAL", "BACTERIAL", "VIRAL"]
))

cm = confusion_matrix(all_labels, all_predictions)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["NORMAL", "BACTERIAL", "VIRAL"]
)

disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Test Accuracy: 78.67%
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       NORMAL       0.75      0.90      0.82       278
#    BACTERIAL       0.86      0.97      0.91       158
#        VIRAL       0.75      0.38      0.50       150
#
#     accuracy                           0.79       586
#    macro avg       0.79      0.75      0.75       586
# weighted avg       0.78      0.79      0.77       586

# %% [markdown]
# Accuracy & Loss Graphs

# %%
# Plot Accuracy
plt.figure(figsize=(8,5))
plt.plot(train_accuracies, label="Train Accuracy")
plt.plot(val_accuracies, label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# Plot Loss
plt.figure(figsize=(8,5))
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()
